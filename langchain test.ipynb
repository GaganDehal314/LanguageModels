# %%
import openai
import langchain
import os

# %%
key = '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'
os.environ['OPENAI_API_KEY'] = key

# %%
from langchain.llms import google_palm
llm =
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 from langchain.llms import google_palm
# ----> 2 llm = palm(temperature = 0.7)
#
# NameError: name 'palm' is not defined

# %%
name = llm('Suggest a unique name for a restaurant that serves Indian food.')
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 name = llm('Suggest a unique name for a restaurant that serves Indian food.')
#
# File ~\anaconda3\envs\LLMs\lib\site-packages\langchain\llms\base.py:876, in BaseLLM.__call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#     869 if not isinstance(prompt, str):
#     870     raise ValueError(
#     871         "Argument `prompt` is expected to be a string. Instead found "
#     872         f"{type(prompt)}. If you want to run the LLM on multiple prompts, use "
#     873         "`generate` instead."
#     874     )
#     875 return (
# --> 876     self.generate(
#     877         [prompt],
#     878         stop=stop,
#     879         callbacks=callbacks,
#     880         tags=tags,
#     881         metadata=metadata,
#     882         **kwargs,
#     883     )
# ...
